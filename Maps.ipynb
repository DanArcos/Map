# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.basemap import Basemap

# %%
data = pd.read_csv('CountryList.csv')
places_visited = data[data['Visited']==True]
visited_coords = places_visited.ix[:,3:5]
# Out:
# array(['Argentina', 'Austria', 'Bahamas', 'Belgium', 'Chile', 'China',
#        'Colombia', 'Costa Rica', 'Czech Republic', 'Ecuador', 'France',
#        'Germany', 'Gibraltar', 'Iceland', 'Ireland', 'Netherlands',
#        'Portugal', 'Spain', 'Taiwan', 'Thailand', 'United States',
#        'Bolivia', 'Peru', 'Morocco', 'Canada', 'The Netherlands', 'Turkey',
#        'Mexico', 'Italy', 'Cambodia'], dtype=object)

# %%
#Set window size
plt.figure(figsize=(20,10),dpi = 100)

# llcrnrlat,llcrnrlon,urcrnrlat,urcrnrlon
# are the lat/lon values of the lower left and upper right corners
# of the map.
# lat_ts is the latitude of true scale.
# resolution = 'c' means use crude resolution coastlines.
# Change Window Size
m = Basemap(projection='merc',llcrnrlat=-80,urcrnrlat=80,\
            llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')
m.drawcoastlines()
m.fillcontinents(color='green',lake_color='skyblue')

# draw parallels and meridians.
m.drawparallels(np.arange(-90.,91.,30.))
m.drawmeridians(np.arange(-180.,181.,60.))
m.drawmapboundary(fill_color='skyblue')

#Plot points
lon = np.array(visited_coords['Longitude'])
lat = np.array(visited_coords['Latitude'])
x,y = m(lon, lat)
m.plot(x, y, 'ro', markersize=3)

plt.title("Countries visited: "+ str(len(places_visited['Country'].unique())))
plt.show()
